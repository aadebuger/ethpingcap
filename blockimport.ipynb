# %%
import pandas as pd
import datetime
def dateparse (time_in_secs):    
    return datetime.datetime.fromtimestamp(float(time_in_secs))

# %%
data = pd.read_csv("~/apps/eth/blocks.csv",index_col='timestamp',parse_dates=True,date_parser=dateparse)

# %%
print(data)
# Out:
#                      number  \
# timestamp
# 1970-01-01 08:00:00       0
# 2015-07-30 23:26:28       1
# 2015-07-30 23:26:57       2
# 2015-07-30 23:27:28       3
# 2015-07-30 23:27:57       4
# 2015-07-30 23:28:03       5
# 2015-07-30 23:28:27       6
# 2015-07-30 23:28:30       7
# 2015-07-30 23:28:32       8
# 2015-07-30 23:28:35       9
# 2015-07-30 23:28:48      10
# 2015-07-30 23:28:56      11
# 2015-07-30 23:29:04      12
# 2015-07-30 23:29:18      13
# 2015-07-30 23:29:21      14
# 2015-07-30 23:29:28      15
# 2015-07-30 23:29:34      16
# 2015-07-30 23:29:38      17
# 2015-07-30 23:29:40      18
# 2015-07-30 23:29:47      19
# 2015-07-30 23:29:49      20
# 2015-07-30 23:29:53      21
# 2015-07-30 23:30:04      22
# 2015-07-30 23:30:08      23
# 2015-07-30 23:30:13      24
# 2015-07-30 23:30:14      25
# 2015-07-30 23:30:16      26
# 2015-07-30 23:30:23      27
# 2015-07-30 23:30:28      28
# 2015-07-30 23:30:39      29
# ...                     ...
# ...

# %%
import pandas as pd
filename='/home/aadebuger/GEXTMAC/ethereum1t/etldata/transactions.csv'
tv = pd.read_csv(filename)

print("test1")
# Out:
# test1

# %%
print(len(data))
l=0
r=100
length =len(data)
while(l<length):
    data[l:r].to_sql(name='block', con=con, if_exists='append', index=False,chunksize=100)
    print("to_sql ok")
    l+=100
    r+=100
# Out:
# 500001
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# to_sql ok
# ...

# %%
print("hello")
# Out:
# hello
